# %% [markdown]
# # Sales Prediction for Big Mart Outlets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv(r'E:\data science\1\train_v9rqX0R.csv')

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# # Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# # Data Visualisation

# %%
data.plot(kind='density', subplots=True, \
             sharex=False)
plt.show()

# %%
data.plot(kind='box', subplots=True, \
             layout=(4,4), sharex=False, sharey=False)
plt.show()

# %%
sns.heatmap(data.isnull(),yticklabels = False , cbar = False, cmap = 'viridis')

# %%
sns.pairplot(data = data)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\DELL\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Item_Fat_Content', data=data,order=sorted(data['Item_Fat_Content'].unique()))

# %%
data1 = data.dropna()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Outlet_Size', data=data1,order=sorted(data1['Outlet_Size'].unique()))

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Outlet_Type', data=data,order=sorted(data['Outlet_Type'].unique()))

# %%
plt.figure(figsize=(30,8))
sns.countplot(x='Item_Type', data=data,order=sorted(data['Item_Type'].unique()))

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(y='Item_Outlet_Sales',data=data,palette='winter')

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(y='Item_Visibility',data=data,palette='winter')

# %%
sns.jointplot(x='Item_MRP',y='Item_Outlet_Sales',data=data,color='red',kind='kde');

# %%
sns.jointplot(x='Item_Visibility',y='Item_Outlet_Sales',data=data,color='red',kind='kde')

# %%
corre_mat = df.corr()
top_corr_feat = corre_mat.index
plt.figure(figsize=(20,20))
g = sns.heatmap(df[top_corr_feat].corr(),annot = True,cmap = 'RdYlGn')

# %% [markdown]
# # Filling missing value

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Outlet_Size',y='Item_Weight',data=data,palette='winter')

# %%
data[data['Outlet_Size']=='Medium']['Item_Weight'].mean()
# Out:
# 12.895419806243213

# %%
data[data['Outlet_Size']=='Medium']['Item_Weight'].mean()
# Out:
# 12.895419806243213

# %%
data[data['Outlet_Size']=='High']['Item_Weight'].mean()
# Out:
# 13.006148068669578

# %%
data[data['Outlet_Size']=='Small']['Item_Weight'].mean()
# Out:
# 12.848075268817151

# %%
data['Item_Weight'].hist(bins = 20)

# %%
def impute_weight(cols):
    Item_Weight = cols[0]
    Outlet_Size = cols[1]
    if pd.isnull(Item_Weight):
        if Outlet_Size == 'Medium':
            return 12.89
        elif Outlet_Size == 'Small':
            return 12.84
        elif Outlet_Size == 'High':
            return 13.00
    else:
        return Item_Weight

# %%
data['Item_Weight'] = data[['Item_Weight', 'Outlet_Size']].apply(impute_weight, axis = 1)

# %%
W_mean = data.groupby('Outlet_Size')['Item_Weight'].mean()
W_mean
W_mean
# Out:
# Outlet_Size
# High      13.006148
# Medium    12.893605
# Small     12.846290
# Name: Item_Weight, dtype: float64

# %%
data['Item_Weight'].hist(bins = 20)

# %%
data['Outlet_Size'] = data['Outlet_Size'].fillna(data['Outlet_Size'].mode()[0])

# %%
data['Item_Fat_Content'].head(5)
# Out:
# 0    Low Fat
# 1    Regular
# 2    Low Fat
# 3    Regular
# 4    Low Fat
# Name: Item_Fat_Content, dtype: object

# %%
data['Item_Fat_Content'] = data['Item_Fat_Content'].replace({'LF':'Low Fat', 'low fat':'Low Fat','reg':'Regular'})

# %%
data['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %% [markdown]
# Concatinating Train and Test Dataset to do Data Preprocessing

# %%
test = pd.read_csv('saletest.csv')

# %%
test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300          Regular         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38       12.890          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
finaldf = pd.concat([data,test],axis = 0)

# %%
finaldf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 1              DRC01         5.92          Regular         0.019278
# 2              FDN15        17.50          Low Fat         0.016760
# 3              FDX07        19.20          Regular         0.000000
# 4              NCD19         8.93          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 5676           FDB58        10.50          Regular         0.013496
# 5677           FDD47         7.60          Regular         0.142991
# 5678           NCO17        10.00          Low Fat         0.073529
# 5679           FDJ26        15.30          Regular         0.000000
# 5680           FDU37         9.50          Regular         0.104720
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# # Data Preprocessing

# %%
finaldf = pd.get_dummies(finaldf, columns = ['Outlet_Location_Type','Outlet_Size'])

# %%
finaldf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 1              DRC01         5.92          Regular         0.019278
# 2              FDN15        17.50          Low Fat         0.016760
# 3              FDX07        19.20          Regular         0.000000
# 4              NCD19         8.93          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 5676           FDB58        10.50          Regular         0.013496
# 5677           FDD47         7.60          Regular         0.142991
# 5678           NCO17        10.00          Low Fat         0.073529
# 5679           FDJ26        15.30          Regular         0.000000
# 5680           FDU37         9.50          Regular         0.104720
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la = LabelEncoder()
finaldf['Item_Identifier'] = la.fit_transform(finaldf['Item_Identifier'])

# %%
finaldf['Outlet_Identifier'] = la.fit_transform(finaldf['Outlet_Identifier'])

# %%
finaldf['Item_Type'] = la.fit_transform(finaldf['Item_Type'])

# %%
finaldf['Outlet_Type'] = la.fit_transform(finaldf['Outlet_Type'])

# %%
#finaldf['Outlet_Size'] = la.fit_transform(finaldf['Outlet_Size'])

# %%
finaldf['Item_Fat_Content'] = la.fit_transform(finaldf['Item_Fat_Content'])

# %%
#finaldf['Outlet_Location_Type'] = la.fit_transform(finaldf['Outlet_Location_Type'])

# %%
finaldf['Outlet_Type']
# Out:
# 0       1
# 1       2
# 2       1
# 3       0
# 4       1
#        ..
# 5676    1
# 5677    2
# 5678    1
# 5679    1
# 5680    1
# Name: Outlet_Type, Length: 14204, dtype: int32

# %%
#finaldf_map = finaldf.Outlet_Establishment_Year.value_counts().to_dict()

# %%
#finaldf.Outlet_Establishment_Year = finaldf.Outlet_Establishment_Year.map(finaldf_map)
#finaldf

# %%
#finaldf_map1 = finaldf.Item_Identifier.value_counts().to_dict()

# %%
#finaldf.Item_Identifier = finaldf.Item_Identifier.map(finaldf_map1)
#finaldf

# %%
#finaldf_map2 = finaldf.Outlet_Identifier.value_counts().to_dict()

# %%
#finaldf.Outlet_Identifier = finaldf.Outlet_Identifier.map(finaldf_map2)
#finaldf

# %%
titles = list(finaldf.columns)
titles
# Out:
# ['Item_Identifier',
#  'Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_Type',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Type',
#  'Item_Outlet_Sales',
#  'Outlet_Location_Type_Tier 1',
#  'Outlet_Location_Type_Tier 2',
#  'Outlet_Location_Type_Tier 3',
#  'Outlet_Size_High',
#  'Outlet_Size_Medium',
#  'Outlet_Size_Small']

# %%
titles[9],titles[15] = titles[15] ,titles[9]

# %%
df = finaldf[titles]

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156         9.30                 0         0.016047
# 1                   8         5.92                 1         0.019278
# 2                 662        17.50                 0         0.016760
# 3                1121        19.20                 1         0.000000
# 4                1297         8.93                 0         0.000000
# ...               ...          ...               ...              ...
# 5676              233        10.50                 1         0.013496
# 5677              308         7.60                 1         0.142991
# 5678             1426        10.00                 0         0.073529
# 5679              521        15.30                 1         0.000000
# 5680              997         9.50                 1         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.to_csv('finaldf.csv', index = False)

# %%
finaldf = pd.read_csv('finaldf.csv')

# %% [markdown]
# # Feature Transformation

# %% [markdown]
# After data visualisation we see that Item_Visibility feature has
# data distribution towards left that means
# it is not normally distributed hence we take log normal of Item_Visibility to better fit model

# %%
num2 = finaldf['Item_Visibility']._get_numeric_data()

# %%
num2[num2 == 0.000000] = 1

# %%
finaldf['Item_Visibility'] = finaldf['Item_Visibility'] ** -3

# %%
finaldf['Item_Visibility']
# Out:
# 0        241988.096672
# 1        139572.376772
# 2        212408.614831
# 3             1.000000
# 4             1.000000
#              ...
# 14199    406761.467125
# 14200       342.038377
# 14201      2515.543317
# 14202         1.000000
# 14203       870.781554
# Name: Item_Visibility, Length: 14204, dtype: float64

# %%
finaldf['Item_Visibility'] = np.log(finaldf['Item_Visibility'])
finaldf['Item_Visibility'].hist(bins = 20)

# %%
finaldf['Item_Visibility']
# Out:
# 0        12.396644
# 1        11.846339
# 2        12.266267
# 3         0.000000
# 4         0.000000
#            ...
# 14199    12.915982
# 14200     5.834923
# 14201     7.830244
# 14202     0.000000
# 14203     6.769391
# Name: Item_Visibility, Length: 14204, dtype: float64

# %%
finaldf['Item_Visibility'].round(4)
# Out:
# 0        12.3966
# 1        11.8463
# 2        12.2663
# 3         0.0000
# 4         0.0000
#           ...
# 14199    12.9160
# 14200     5.8349
# 14201     7.8302
# 14202     0.0000
# 14203     6.7694
# Name: Item_Visibility, Length: 14204, dtype: float64

# %% [markdown]
# # Split Training and Testing Datasets

# %%
df_train  = finaldf.iloc[:8523,:]
df_test = finaldf.iloc[8523:,:]

# %%
df_test.drop(['Item_Outlet_Sales'],axis = 1,inplace = True)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# # Importing all Libraries

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
array = df_train.values
X = array[:,:-1]
Y = array[:,-1]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, \
                                                    random_state=5)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (6392, 15)
# (2131, 15)
# (6392,)
# (2131,)

# %% [markdown]
# Here we creating list of tuples which contain name of the machine learning algorithm
# Scoring accuracy and standerd deviation of model

# %%
models = []
models.append(('LR', LinearRegression()))
models.append(('LASSO', Lasso()))
models.append(('EN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))

# %%
scoring = 'r2'

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=5, shuffle=True, random_state=5)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, \
                                 scoring=scoring) 
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.542896 (0.018220)
# LASSO: 0.542877 (0.018355)
# EN: 0.481861 (0.025925)
# KNN: 0.194961 (0.033076)
# CART: 0.173175 (0.025023)

# %%
scaler = StandardScaler()
rescaled_X = scaler.fit_transform(X_train)
scaler_Y = StandardScaler()
rescaled_Y = scaler_Y.fit_transform(Y_train.reshape(-1, 1))

# %%
 pipelines = []
 pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()),('LR', LinearRegression())])))
 pipelines.append(('ScaledLASSO', Pipeline([('Scaler', StandardScaler()),('LASSO', Lasso())])))
 pipelines.append(('ScaledEN', Pipeline([('Scaler', StandardScaler()),('EN', ElasticNet())])))
 pipelines.append(('ScaledKNN', Pipeline([('Scaler', StandardScaler()),('KNN', KNeighborsRegressor())])))
 pipelines.append(('ScaledCART', Pipeline([('Scaler', StandardScaler()),('CART', DecisionTreeRegressor())])))
results = []
names = []

for name, model in models:
    kfold = KFold(n_splits=5, shuffle=True, random_state=5)
    cv_results = cross_val_score(model, rescaled_X, rescaled_Y, cv=kfold, scoring = scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.543278 (0.018246)
# LASSO: -0.000480 (0.000252)
# EN: 0.047152 (0.002385)
# KNN: 0.495922 (0.017774)
# CART: 0.166348 (0.019946)

# %%
ensembles = []
ensembles.append(('AB', AdaBoostRegressor()))
ensembles.append(('GBM', GradientBoostingRegressor()))
ensembles.append(('RF', RandomForestRegressor()))
ensembles.append(('ET', ExtraTreesRegressor()))
results = []
names = []
for name, model in ensembles:
    kfold = KFold(n_splits=5, shuffle=True, random_state=5)
    cv_results = cross_val_score(model,X_train,Y_train,cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# AB: 0.492866 (0.051770)
# GBM: 0.596494 (0.016745)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
param_grid = dict(n_estimators=np.array([50,51,52,53,54]))
                                            
model = GradientBoostingRegressor(random_state=5)
kfold = KFold(n_splits=5, shuffle=True, random_state=5)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(X_train, Y_train)

print("Best: %f using %s" % (grid_result.best_score_,grid_result.best_params_))

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.599124 using {'n_estimators': 50}
# 0.599124 (0.015921) with: {'n_estimators': 50}
# 0.599068 (0.016222) with: {'n_estimators': 51}
# 0.599035 (0.015931) with: {'n_estimators': 52}
# 0.599054 (0.015920) with: {'n_estimators': 53}
# 0.598970 (0.015988) with: {'n_estimators': 54}

# %%
model = GradientBoostingRegressor(random_state=5, n_estimators=50)
model.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=50,
#                           n_iter_no_change=None, presort='auto', random_state=5,
#                           subsample=1.0, tol=0.0001, validation_fraction=0.1,
#                           verbose=0, warm_start=False)

# %%
predictions = model.predict(X_test)
print(mean_squared_error(Y_test, predictions))
root_mean_squared_error = np.sqrt(mean_squared_error(Y_test, predictions))
print(root_mean_squared_error)
# Out:
# 1180807.3934911564
# 1086.6496185482956

# %%
pred = model.predict(df_test)

# %%
pred
# Out:
# array([1644.34677528, 1409.85794483,  635.88543934, ..., 1920.81703352,
#        3448.52963201, 1325.25449031])

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 8523 to 14203
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Item_Identifier              5681 non-null   int64
#  1   Item_Weight                  5681 non-null   float64
#  2   Item_Fat_Content             5681 non-null   int64
#  3   Item_Visibility              5681 non-null   float64
#  4   Item_Type                    5681 non-null   int64
#  5   Item_MRP                     5681 non-null   float64
#  6   Outlet_Identifier            5681 non-null   int64
#  7   Outlet_Establishment_Year    5681 non-null   int64
#  8   Outlet_Type                  5681 non-null   int64
#  9   Outlet_Size_Small            5681 non-null   int64
#  10  Outlet_Location_Type_Tier 1  5681 non-null   int64
#  11  Outlet_Location_Type_Tier 2  5681 non-null   int64
#  12  Outlet_Location_Type_Tier 3  5681 non-null   int64
# ...

# %%
pred=pd.DataFrame(pred)
sub_df=pd.read_csv(r'E:\data science\1\sample_submission_8RXa3c6.csv')
datasets=pd.concat([sub_df['Item_Identifier'],pred],axis=1)
datasets=pd.concat([sub_df['Outlet_Identifier'],datasets],axis=1)
datasets.columns=['Outlet_Identifier','Item_Identifier','Item_Outlet_Sales']
datasets.to_csv('sample.csv',index=False)

# %%
d = pd.read_csv('sample.csv')

# %%
d
# Out:
#      Outlet_Identifier Item_Identifier  Item_Outlet_Sales
# 0               OUT049           FDW58        1644.346775
# 1               OUT017           FDW14        1409.857945
# 2               OUT010           NCN55         635.885439
# 3               OUT017           FDQ58        2442.747632
# 4               OUT027           FDY38        6038.437149
# ...                ...             ...                ...
# 5676            OUT046           FDB58        2201.312711
# 5677            OUT018           FDD47        2418.888063
# 5678            OUT045           NCO17        1920.817034
# 5679            OUT017           FDJ26        3448.529632
# 5680            OUT045           FDU37        1325.254490
#
# [5681 rows x 3 columns]

# %%
titles = list(d.columns)
titles
titles[0],titles[1] = titles[1] ,titles[0]
d = d[titles]

# %%
d
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049        1644.346775
# 1              FDW14            OUT017        1409.857945
# 2              NCN55            OUT010         635.885439
# 3              FDQ58            OUT017        2442.747632
# 4              FDY38            OUT027        6038.437149
# ...              ...               ...                ...
# 5676           FDB58            OUT046        2201.312711
# 5677           FDD47            OUT018        2418.888063
# 5678           NCO17            OUT045        1920.817034
# 5679           FDJ26            OUT017        3448.529632
# 5680           FDU37            OUT045        1325.254490
#
# [5681 rows x 3 columns]

# %%
d.to_csv('sampled.csv', index = False)
